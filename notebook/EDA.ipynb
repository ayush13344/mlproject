# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# Running cells with 'penv (Python 3.8.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\nagpa\.vscode\mlproject\penv ipykernel --update-deps --force-reinstall'

# %%
df=pd.read_csv('data/student_performance.csv')

# %%
df.head()

# %%
##missing value
df.isna().sum()

# %%
##check duplicates
df.duplicated().sum()

# %%
##check data types
df.info()

# %%
df.unique()
df.describe()

# %%
##exploring data
print("categories in 'gender' variable : ",end=" ")
print(df['gender'].unique())

print("categories in 'race_ethnicity' variable : ",end=" ")
print(df['race_ethnicity'].unique())

print("categories in 'parental_level_of_education' variable : ",end=" ")
print(df['parental_level_of_education'].unique())

print("categories in 'lunch' variable : ",end=" ")
print(df['lunch'].unique())

print("categories in 'test_preparation_course' variable : ",end=" ")
print(df['test_preparation_course'].unique())

# %%
numeric_features=[feature for feature in df.columns if df[feature].dtype!='O']
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']  

print("Numeric features length: ",len(numeric_features))
print("Categorical features length: ",len(categorical_features))

# %%
df['total score']=df['math_score']+df['reading_score']+df['writing_score']
df['average score']=df['total score']/3
df.head()

# %%
reading_full=df[df['reading_score']==100]['average'].count()
writing_full=df[df['writing_score']==100]['average'].count()
math_full=df[df['math_score']==100]['average'].count()

print("Number of students with full score in reading: ",reading_full)
print("Number of students with full score in writing: ",writing_full)
print("Number of students with full score in math: ",math_full)

# %%
reading_less_20=df[df['reading_score']<=20]['average'].count()
writing_less_20=df[df['writing_score']<=20]['average'].count()
math_less_20=df[df['math_score']<=20]['average'].count()

print("Number of students with less than or equal to 20 score in reading: ",reading_less_20)
print("Number of students with less than or equal to 20 score in writing: ",writing_less_20)
print("Number of students with less than or equal to 20 score in math: ",math_less_20)

# %%
##histogram
fig,axes=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='average',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()

# %%
##histogram
fig,axes=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data=df,x='total score',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',kde=True,hue='gender')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='parental_level_of_education')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental_level_of_education')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race_ethinicity')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race_ethnicity')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('math score')
sns.violinplot(y='math_score',data=df,color='orange',linewidth=3)
plt.subplot(1,2,2)
plt.title('reading score')
sns.violinplot(y='reading_score',data=df,color='lightblue',linewidth=3)
plt.subplot(1,2,3)
plt.title('writing score')  
sns.violinplot(y='writing_score',data=df,color='lightgreen',linewidth=3)
plt.show()

# %%
##multivariate analysis
plt.rcParams['figure.figsize']=(30,12)

plt.subplot(1,5,1)
size=df['gender'].value_counts()
labels='Female',"Male"
color=['red','green']

plt.pie(size,labels=labels,colors=color,autopct='%1.1f%%',startangle=90,explode=[0.1,0],shadow=True)
plt.title('gender')

plt.subplot(1,5,2)
size=df['race_ethnicity'].value_counts()
labels="Group A","Group B","Group C","Group D","Group E"
color=['red','green','blue','yellow','orange']

plt.pie(size,colors=color,labels=labels,autopct='%1.1f%%',startangle=90,explode=[0.1,0,0,0,0],shadow=True)
plt.title('race/ethnicity')

plt.subplot(1,5,3)
size=df['parental_level_of_education'].value_counts()
labels="Some college","Associate's degree","High school","Some high school","Bachelor's degree","Master's degree"
color=['red','green','blue','yellow','orange','purple']

plt.pie(size,labels=labels,colors=color,autopct='%1.1f%%',startangle=90,explode=[0.1,0],shadow=True)
plt.title('parental level of education')

plt.subplot(1,5,4)
size=df['test_preparation_course'].value_counts()
labels="Completed","None"
color=['red','green']

plt.pie(size,labels=labels,colors=color,autopct='%1.1f%%',startangle=90,explode=[0.1,0],shadow=True)
plt.title('test preparation course')

plt.subplot(1,5,5)
size=df['lunch'].value_counts()
labels="Standard","Free"
color=['red','green']

plt.pie(size,labels=labels,colors=color,autopct='%1.1f%%',startangle=90,explode=[0.1,0],shadow=True)
plt.title('lunch')

plt.tight_layout()
plt.grid()
plt.show()

# %%
##gender distribution
f,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=df['gender'],data=df,palette='Set1',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

    plt.pie(x=df['gender'].value_counts(), labels=['Female', 'Male'], colors=['red', 'green'], autopct='%1.1f%%', startangle=90, explode=[0.1, 0], shadow=True)
    plt.show()

# %%
##bivariate analysis
gender_grp=df.groupby('gender').mean()
gender_grp

# %%
plt.figure(figsize=(15,6))
X=['Total Average','Math Average']

female_scores=[gender_grp['average'][0],gender_grp['math_score'][0]]
male_scores=[gender_grp['average'][1],gender_grp['math_score'][1]]
X_axis=np.arange(len(X))

plt.bar(X_axis-0.2,female_scores,width=0.4,label='Female',color='red')
plt.bar(X_axis+0.2,male_scores,width=0.4,label='Male',color='blue')

plt.xticks(X_axis,X)
plt.xlabel('Scores')
plt.ylabel('Average Scores')
plt.show()

# %%
##univariate of race
##gender distribution
f,ax=plt.subplots(1,2,figsize=(15,7))
sns.countplot(x=df['race_ethnicity'],data=df,palette='Set1',ax=ax[0],saturation=0.95)
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

    plt.pie(x=df['race_ethnicity'].value_counts(), labels=df['race_ethnicity'].value_counts().index, colors=sns.color_palette('Set1', n_colors=len(df['race_ethnicity'].value_counts())), autopct='%1.1f%%', startangle=90, explode=[0.1]*len(df['race_ethnicity'].value_counts()), shadow=True)
    plt.show()

# %%
Group_data=df.groupby('race_ethnicity')
f,ax=plt.subplots(2,3,figsize=(20,10))
sns.barplot(x=Group_data['math_score'].mean().index, y=Group_data['math_score'].mean(), palette='Set1', ax=ax[0,0])
ax[0,0].set_title('Average Math Score by Race/Ethnicity')

for container in ax[0,0].containers:
    ax[0,0].bar_label(container,color='black',size=12)

sns.barplot(x=Group_data['reading_score'].mean().index, y=Group_data['reading_score'].mean(), palette='Set1', ax=ax[0,1])
ax[0,1].set_title('Average Reading Score by Race/Ethnicity')

for container in ax[0,1].containers:
    ax[0,1].bar_label(container,color='black',size=12)

sns.barplot(x=Group_data['writing_score'].mean().index, y=Group_data['writing_score'].mean(), palette='Set1', ax=ax[0,2])
ax[0,2].set_title('Average Writing Score by Race/Ethnicity')

for container in ax[0,2].containers:
    ax[0,2].bar_label(container,color='black',size=12)

sns.barplot(x=Group_data['total score'].mean().index, y=Group_data['total score'].mean(), palette='Set1', ax=ax[1,0])

# %%
df.groupby('parental_level_of_education').agg('mean').plot(kind='bar',figsize=(15,7),color=['red','green','blue','yellow'])
plt.legend(['math score','reading score','writing score','total score','average'])
plt.title('Average Scores by Parental Level of Education')
plt.show()

# %%
##univariate of lunch
plt.rcParams['figure.figsize']=(15,7)
plt.style.use('seaborn-talk')
sns.countplot(x=df['lunch'],data=df,palette='Set1',saturation=0.95)
plt.show()

# %%
##bivariate analysis of lunch
f,ax=plt.subplots(1,2,figsize=(15,7))
sns.barplot(x=df['lunch'],y=df['average'],data=df,palette='Set1',ax=ax[0])
for container in ax[0].containers:
    ax[0].bar_label(container,color='black',size=15)

sns.countplot(x=df['lunch'],data=df,palette='Set1',saturation=0.95,hue='lunch')
for container in ax[1].containers:
    ax[1].bar_label(container,color='black',size=15)

# %%
##bivariate for test prep
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.barplot(x=df['lunch'],y=df['math_score'],hue=df['test_preparation_course'],data=df,palette='Set1')
plt.subplot(1,2,2)
sns.barplot(x=df['lunch'],y=df['reading_score'],hue=df['test_preparation_course'],data=df,palette='Set1')
plt.subplot(1,2,3)
sns.barplot(x=df['lunch'],y=df['writing_score'],hue=df['test_preparation_course'],data=df,palette='Set1')
plt.show()

# %%
##checking outliers
plt.subplots(1,3,figsize=(20,6))
plt.subplot(131)
sns.boxplot(x=df['math_score'],data=df,palette='Set1')
plt.subplot(132)
sns.boxplot(x=df['reading_score'],data=df,palette='Set1')
plt.subplot(133)
sns.boxplot(x=df['writing_score'],data=df,palette='Set1')
plt.subplot(134)
sns.boxplot(x=df['average'],data=df,palette='Set1')

# %%
##multivariate using pairplot
sns.pairplot(df,hue='gender')
plt.show()
